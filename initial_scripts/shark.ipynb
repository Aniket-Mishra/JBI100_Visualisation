# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import plotly.graph_objects as go

import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

import datapane as dp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# !pip3 install numpy pandas matplotlib seaborn plotly cufflinks statsmodels datapane
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.24.2)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.0.0)
# Collecting matplotlib
#   Downloading matplotlib-3.9.3-cp310-cp310-macosx_11_0_arm64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 10.5 MB/s eta 0:00:0000:0100:01
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 11.1 MB/s eta 0:00:00
# Collecting plotly
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 11.0 MB/s eta 0:00:0000:0100:01
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 11.3 MB/s eta 0:00:0000:0100:01
# Collecting datapane
#   Downloading datapane-0.17.0-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.6/143.6 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 6.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.3/253.3 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Collecting packaging>=20.0
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.2-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Collecting pillow>=8
#   Downloading pillow-11.0.0-cp310-cp310-macosx_11_0_arm64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 11.3 MB/s eta 0:00:0000:0100:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Collecting six>=1.9.0
#   Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cufflinks) (65.5.0)
# Collecting ipython>=5.3.0
#   Downloading ipython-8.30.0-py3-none-any.whl (820 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.8/820.8 kB 10.5 MB/s eta 0:00:0000:0100:01
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 8.2 MB/s eta 0:00:00
# Collecting scipy!=1.9.2,>=1.8
#   Downloading scipy-1.14.1-cp310-cp310-macosx_14_0_arm64.whl (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 10.8 MB/s eta 0:00:0000:0100:01
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=9.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from datapane) (18.0.0)
# Collecting dominate<3.0.0,>=2.7.0
#   Downloading dominate-2.9.1-py2.py3-none-any.whl (29 kB)
# Collecting packaging>=20.0
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.5 MB/s eta 0:00:00
# Collecting typing-extensions<5.0.0,>=4.4.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting altair<6.0.0,>=5.0.0
#   Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 8.3 MB/s eta 0:00:00a 0:00:01
# Collecting ipynbname>=2021.3.2
#   Downloading ipynbname-2024.1.0.0-py3-none-any.whl (4.3 kB)
# Collecting multimethod<2.0.0,>=1.9.0
#   Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Collecting micawber>=0.5.3
#   Downloading micawber-0.5.6.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting vega-datasets<1.0.0,>=0.9.0
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: chardet<6.0.0,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from datapane) (5.1.0)
# Collecting colorlog<7.0.0,>=6.4.0
#   Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Collecting pandas
#   Downloading pandas-1.5.3-cp310-cp310-macosx_11_0_arm64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 10.2 MB/s eta 0:00:0000:0100:01
# Collecting lxml<5.0.0,>=4.7.1
#   Downloading lxml-4.9.4.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 11.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting importlib_resources>=5.6.0
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting jinja2
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 7.7 MB/s eta 0:00:00
# Collecting narwhals>=1.14.2
#   Downloading narwhals-1.15.2-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 10.3 MB/s eta 0:00:00
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 5.9 MB/s eta 0:00:00
# Collecting ipykernel
#   Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 8.3 MB/s eta 0:00:00
# Collecting jedi>=0.16
#   Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Collecting traitlets>=5.13.0
#   Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 8.4 MB/s eta 0:00:00
# Collecting pygments>=2.4.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.5 MB/s eta 0:00:0000:0100:01
# Collecting stack_data
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41
#   Downloading prompt_toolkit-3.0.48-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 10.3 MB/s eta 0:00:00
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting pexpect>4.3
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 7.4 MB/s eta 0:00:00
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting comm>=0.1.3
#   Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Collecting widgetsnbextension~=4.0.12
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.6 MB/s eta 0:00:00a 0:00:01
# Collecting jupyterlab-widgets~=3.0.12
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 9.5 MB/s eta 0:00:00
# Collecting parso<0.9.0,>=0.8.4
#   Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 6.4 MB/s eta 0:00:00
# Collecting attrs>=22.2.0
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 6.6 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.22.3-cp310-cp310-macosx_11_0_arm64.whl (349 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.0/349.0 kB 10.0 MB/s eta 0:00:00
# Collecting referencing>=0.28.4
#   Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting pyzmq>=24
#   Downloading pyzmq-26.2.0-cp310-cp310-macosx_10_15_universal2.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.5 MB/s eta 0:00:00a 0:00:01
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Collecting tornado>=6.1
#   Downloading tornado-6.4.2-cp38-abi3-macosx_10_9_universal2.whl (436 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.3/436.3 kB 10.0 MB/s eta 0:00:0000:01
# Collecting psutil
#   Downloading psutil-6.1.0-cp36-abi3-macosx_11_0_arm64.whl (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.8/248.8 kB 9.4 MB/s eta 0:00:00
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 7.6 MB/s eta 0:00:00
# Collecting debugpy>=1.6.5
#   Downloading debugpy-1.8.9-py2.py3-none-any.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 10.3 MB/s eta 0:00:0000:0100:01
# Collecting appnope
#   Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Collecting executing>=1.2.0
#   Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, micawber, colorlover, widgetsnbextension, typing-extensions, traitlets, tornado, tenacity, six, scipy, rpds-py, pyzmq, pyparsing, pygments, psutil, prompt_toolkit, platformdirs, pillow, pexpect, patsy, parso, packaging, nest-asyncio, narwhals, multimethod, MarkupSafe, lxml, jupyterlab-widgets, importlib_resources, fonttools, executing, exceptiongroup, dominate, decorator, debugpy, contourpy, colorlog, attrs, asttokens, appnope, stack_data, referencing, plotly, matplotlib-inline, jupyter-core, jinja2, jedi, comm, pandas, matplotlib, jupyter-client, jsonschema-specifications, ipython, vega-datasets, statsmodels, seaborn, jsonschema, ipywidgets, ipykernel, ipynbname, cufflinks, altair, datapane
#   DEPRECATION: micawber is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for micawber ... done
#   DEPRECATION: lxml is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for lxml ... done
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.0
#     Uninstalling pandas-2.0.0:
# ERROR: Could not install packages due to an OSError: Cannot move the non-empty directory '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas-2.0.0.dist-info/': Lacking write permission to '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas-2.0.0.dist-info/'.
#
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import streamlit as st

# %%
df = pd.read_excel("/Users/paniket/TU_Eindhoven/2_Study/Q2_JBI100_Visualisation_4/4_Code/JBI100_Visualisation/JBI100_Data_2024_2025/Australian_Shark_Incidents/Australian Shark-Incident Database Public Version.xlsx", sheet_name="ASID")

# %%
df.head(3)

# %%
df.info()

# %%
# Streamlit Title and Filters
st.title("Interactive Shark Attack Data Explorer")
st.sidebar.header("Filter Options")

# Filter by Year
year_range = st.sidebar.slider(
    "Select Year Range",
    int(df["Incident.year"].min()),
    int(df["Incident.year"].max()),
    (1900, 2023)
)
filtered_data = df[(df["Incident.year"] >= year_range[0]) & (df["Incident.year"] <= year_range[1])]

# Filter by State
state_filter = st.sidebar.multiselect(
    "Select State(s)",
    options=df["State"].unique(),
    default=df["State"].unique()
)
filtered_data = filtered_data[filtered_data["State"].isin(state_filter)]

# %%
fig1 = px.line(
    filtered_data.groupby("Incident.year").size().reset_index(name="Count"),
    x="Incident.year",
    y="Count",
    title="Shark Attacks Over Time",
    labels={"Incident.year": "Year", "Count": "Number of Incidents"}
)
st.plotly_chart(fig1)

# %%
fig2 = px.histogram(
    filtered_data,
    x="Site.category",
    color="Injury.severity",
    title="Attack Severity by Site Category",
    labels={"Site.category": "Site Category", "Injury.severity": "Severity"}
)
st.plotly_chart(fig2)

# %%
# Check for NaN and invalid values
print(filtered_data["Shark.length.m"].isnull().sum())  # Count NaN values
print(filtered_data["Shark.length.m"].unique())  # Check unique values

# %%
# Convert to numeric and handle errors
filtered_data["Shark.length.m"] = pd.to_numeric(filtered_data["Shark.length.m"], errors="coerce")

# Replace NaN values with a default size, such as the mean or a small default value
filtered_data["Shark.length.m"] = filtered_data["Shark.length.m"].fillna(1)  # Replace NaN with 1

# Alternatively, drop rows with NaN in Shark.length.m
# filtered_data = filtered_data.dropna(subset=["Shark.length.m"])

# %%
filtered_data["Shark.length.m"].unique()[-1]

# %%
fig3 = px.scatter_geo(
    filtered_data,
    lat="Latitude",
    lon="Longitude",
    color="Injury.severity",
    size="Shark.length.m",
    title="Geographic Distribution of Shark Attacks",
    labels={"Latitude": "Latitude", "Longitude": "Longitude"},
    projection="natural earth"
)

fig3.show()

# %%
fig4 = px.bar(
    filtered_data,
    x="Victim.activity",
    color="Provoked/unprovoked",
    title="Victim Activities and Provocation",
    labels={"Victim.activity": "Activity", "Provoked/unprovoked": "Provocation Type"}
)
st.plotly_chart(fig4)

# %%
fig5 = px.bar(
    filtered_data,
    x="Shark.common.name",
    color="Injury.severity",
    title="Shark Species Involved in Incidents",
    labels={"Shark.common.name": "Shark Species", "Injury.severity": "Severity"}
)
st.plotly_chart(fig5)

# %%
# Graph Selection
graph_choice = st.sidebar.selectbox(
    "Select a Graph to Display",
    options=["Shark Attacks Over Time", "Attack Severity by Site Category", 
             "Geographic Distribution", "Victim Activity and Provocation", "Shark Species Involved"]
)

# Display the chosen graph
if graph_choice == "Shark Attacks Over Time":
    st.plotly_chart(fig1)
elif graph_choice == "Attack Severity by Site Category":
    st.plotly_chart(fig2)
elif graph_choice == "Geographic Distribution":
    st.plotly_chart(fig3)
elif graph_choice == "Victim Activity and Provocation":
    st.plotly_chart(fig4)
elif graph_choice == "Shark Species Involved":
    st.plotly_chart(fig5)

# %%
streamlit run shark_attacks_app.py
