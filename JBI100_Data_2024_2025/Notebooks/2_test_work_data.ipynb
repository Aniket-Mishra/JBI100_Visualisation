# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import plotly.graph_objects as go

import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

import datapane as dp
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.io as pio

# Create a custom default template
custom_template = pio.templates["plotly_white"]  # Start with an existing template
custom_template.layout.title.font.size = 16
custom_template.layout.title.x = 0.5  # Center titles
custom_template.layout.xaxis.title.font.size = 14
custom_template.layout.yaxis.title.font.size = 14
custom_template.layout.margin = dict(l=40, r=40, t=40, b=40)  # Adjust margins
custom_template.layout.legend.font.size = 12

# Register the custom template globally
pio.templates["custom_template"] = custom_template

# Set it as the default template
pio.templates.default = "plotly_white+custom_template"

# %%
## Figure wide defaults and example

# def set_plot_defaults(fig):
#     fig.update_layout(
#         font=dict(size=14),  # Default font size
#         title=dict(x=0.5),  # Center titles
#         margin=dict(l=50, r=50, t=50, b=50),  # Margins
#         legend=dict(font=dict(size=12))  # Legend font size
#     )
#     return fig

# fig = px.bar(df, x="incident_outcome", y="count", title="Incident Outcome Distribution")
# fig = set_plot_defaults(fig)
# fig.show()

# %%
# ## Notebook wide defaults:
# import plotly.io as pio

# def set_plotly_defaults():
#     pio.renderers.default = "browser"
#     pio.templates.default = "plotly_white"


# # Import to other nbs
# from plotly_defaults import set_plotly_defaults
# set_plotly_defaults()

# %%
df = pd.read_csv(
    "../Work-related Injury and Illness/ITA Case Detail Data 2023 through 8-31-2023.csv",
    delimiter=",",
    low_memory=False,
)

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889447 entries, 0 to 889446
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        889447 non-null  int64
#  1   establishment_id          889447 non-null  int64
#  2   establishment_name        889447 non-null  object
#  3   ein                       812922 non-null  object
#  4   company_name              840391 non-null  object
#  5   street_address            889446 non-null  object
#  6   city                      889447 non-null  object
#  7   state                     889447 non-null  object
#  8   zip_code                  889447 non-null  float64
#  9   naics_code                889447 non-null  int64
#  10  naics_year                888174 non-null  float64
#  11  industry_description      829648 non-null  object
#  12  establishment_type        887563 non-null  float64
#  13  size                      889447 non-null  int64
#  14  annual_average_employees  889447 non-null  int64
#  15  total_hours_worked        889447 non-null  int64
#  16  case_number               889434 non-null  object
#  17  job_description           885793 non-null  object
#  18  soc_code                  889447 non-null  object
#  19  soc_description           889447 non-null  object
#  20  soc_reviewed              889447 non-null  int64
#  21  soc_probability           889447 non-null  float64
#  22  date_of_incident          889447 non-null  object
#  23  incident_outcome          889447 non-null  int64
#  24  dafw_num_away             889447 non-null  int64
#  25  djtr_num_tr               889447 non-null  int64
#  26  type_of_incident          889447 non-null  int64
#  27  time_started_work         777556 non-null  object
#  28  time_of_incident          778479 non-null  object
#  29  time_unknown              887398 non-null  float64
#  30  date_of_death             279 non-null     object
#  31  created_timestamp         889447 non-null  object
#  32  year_filing_for           889447 non-null  int64
# dtypes: float64(5), int64(12), object(16)
# memory usage: 945.6 MB

# %%
df["date_of_incident"] = pd.to_datetime(df["date_of_incident"], errors="coerce")

# %%
df.describe().T
# Out:
#                              count                           mean  \
# id                        889447.0                  451380.236701
# establishment_id          889447.0                  863122.366861
# zip_code                  889447.0                25948429.910993
# naics_code                889447.0                  496292.148951
# naics_year                888174.0                    2021.012598
# establishment_type        887563.0                       1.083898
# size                      889447.0                       9.833503
# annual_average_employees  889447.0                    8200.306033
# total_hours_worked        889447.0                 3528374.320517
# soc_reviewed              889447.0                       0.838397
# soc_probability           889447.0                       1.192423
# date_of_incident            889447  2023-06-30 13:00:28.579105280
# incident_outcome          889447.0                       2.973528
# dafw_num_away             889447.0                      12.804085
# djtr_num_tr               889447.0                      15.531824
# type_of_incident          889447.0                       1.351008
# time_unknown              887398.0                       0.132183
# year_filing_for           889447.0                         2023.0
#
#                                           min                  25%  \
# id                                      680.0             226415.5
# establishment_id                      41940.0             651512.0
# zip_code                                603.0              29601.0
# naics_code                           111110.0             444110.0
# naics_year                             2012.0               2022.0
# establishment_type                        0.0                  1.0
# size                                      1.0                  3.0
# annual_average_employees                  0.0                149.0
# total_hours_worked                        0.0             235685.0
# soc_reviewed                              0.0                  0.0
# soc_probability                           0.0             0.802269
# date_of_incident          2022-02-26 00:00:00  2023-03-31 00:00:00
# incident_outcome                          1.0                  2.0
# dafw_num_away                             0.0                  0.0
# djtr_num_tr                               0.0                  0.0
# type_of_incident                          1.0                  1.0
# time_unknown                              0.0                  0.0
# year_filing_for                        2023.0               2023.0
#
#                                           50%                  75%  \
# id                                   451770.0             675989.5
# establishment_id                     989369.0            1140101.0
# zip_code                              53146.0              84663.0
# naics_code                           491110.0             622110.0
# naics_year                             2022.0               2022.0
# establishment_type                        1.0                  1.0
# size                                      3.0                 22.0
# annual_average_employees                347.0               1323.0
# total_hours_worked                   584011.0            2125664.0
# soc_reviewed                              1.0                  1.0
# soc_probability                      0.994869             0.999979
# date_of_incident          2023-07-03 00:00:00  2023-09-27 00:00:00
# incident_outcome                          3.0                  4.0
# dafw_num_away                             0.0                  5.0
# djtr_num_tr                               0.0                 13.0
# type_of_incident                          1.0                  1.0
# time_unknown                              0.0                  0.0
# year_filing_for                        2023.0               2023.0
#
#                                           max               std
# id                                   900940.0     259802.354363
# establishment_id                    1246187.0     357576.169569
# zip_code                          997000000.0  132134803.602068
# naics_code                           999999.0     135696.454961
# naics_year                             2022.0          2.873469
# establishment_type                        3.0          0.362637
# size                                     22.0          9.040229
# annual_average_employees          172307584.0    1033831.036612
# total_hours_worked              13833831664.0   24140354.185441
# soc_reviewed                              2.0           0.69882
# soc_probability                           5.0          1.376831
# date_of_incident          2024-08-26 00:00:00               NaN
# incident_outcome                          4.0          0.839186
# dafw_num_away                           640.0         35.737457
# djtr_num_tr                             575.0         34.982631
# type_of_incident                          6.0          1.133985
# time_unknown                              1.0           0.33869
# year_filing_for                        2023.0               0.0

# %%
# fig1 = px.bar(df, x='incident_outcome', title='Distribution of Incident Outcomes', labels={'incident_outcome': 'Incident Outcome'})
# fig1.show()

# %%
df.columns
# Out:
# Index(['id', 'establishment_id', 'establishment_name', 'ein', 'company_name',
#        'street_address', 'city', 'state', 'zip_code', 'naics_code',
#        'naics_year', 'industry_description', 'establishment_type', 'size',
#        'annual_average_employees', 'total_hours_worked', 'case_number',
#        'job_description', 'soc_code', 'soc_description', 'soc_reviewed',
#        'soc_probability', 'date_of_incident', 'incident_outcome',
#        'dafw_num_away', 'djtr_num_tr', 'type_of_incident', 'time_started_work',
#        'time_of_incident', 'time_unknown', 'date_of_death',
#        'created_timestamp', 'year_filing_for'],
#       dtype='object')

# %%
df["type_of_incident"].unique()
# Out:
# array([6, 1, 5, 2, 3, 4])

# %%
df["incident_outcome"].unique()
# Out:
# array([4, 3, 2, 1])

# %%
df.shape
# Out:
# (889447, 33)

# %%
df_agg = df.groupby("incident_outcome").size().reset_index(name="count")
